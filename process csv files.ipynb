# %%
import pandas as pd
import glob

files = glob.glob('D:\lc data\*.csv') 

pd.set_option('display.max_columns', None)

# %%
# For reading columns that are dates
lc_date_parser = lambda date: pd.to_datetime(date, format='%b-%Y', errors='coerce')
date_column_names = ['issue_d', 'earliest_cr_line', 'last_pymnt_d', 'last_credit_pull_d', 'next_pymnt_d' ]

# Read _all_ the csv's
loans = pd.concat( pd.read_csv( f , skiprows=1, header=0, engine='python', parse_dates=date_column_names, date_parser=lc_date_parser, skipfooter=2) for f in files )

# Drop some columns to save space
columns_to_drop = ['url', 'policy_code', 'application_type']
loans.drop( columns_to_drop, axis=1, inplace=True)

# %% [markdown]
# ### String manipulations
# Probably don't need regex for some columns here

# %%
loans['int_rate']		= loans['int_rate'].replace(to_replace='%', value='', regex=True).astype('float16')
loans['revol_util'] 	= loans['revol_util'].replace(to_replace='%', value='', regex=True).astype('float16')
loans['emp_length'] 	= loans['emp_length'].replace( '[^\d]+', '', regex=True).replace('', value=0).astype('int8')
loans['zip_code'] 	= loans['zip_code'].str.replace('xx', '00').astype('int32')
loans['desc'] = loans['desc'].str.replace(r"Borrower added on .*? \>", "").str.strip()

# %% [markdown]
# ### Type conversions
# To reduce memory usage

# %%
# Type conversions for columns I know should be integers or smaller floats
loans['id'] 					= loans['id'].astype('int32')
loans['member_id'] 				= loans['member_id'].astype('int32')
loans['loan_amnt'] 				= loans['loan_amnt'].astype('int32')
loans['funded_amnt'] 				= loans['funded_amnt'].astype('int32')
loans['funded_amnt_inv'] 			= loans['funded_amnt_inv'].astype('int32')
loans['annual_inc'] 				= loans['annual_inc'].astype('int32')

loans['delinq_2yrs'] 				= loans['delinq_2yrs'].astype('int8')
loans['fico_range_low'] 			= loans['fico_range_low'].astype('int16')
loans['fico_range_high'] 			= loans['fico_range_high'].astype('int16')


loans['inq_last_6mths'] 			= loans['inq_last_6mths'].astype('int8')
loans['open_acc'] 				= loans['open_acc'].astype('int8')
loans['revol_bal'] 				= loans['revol_bal'].astype('int32')
loans['total_acc'] 				= loans['total_acc'].astype('int8')

loans['last_fico_range_low'] 		= loans['fico_range_low'].astype('int16')
loans['last_fico_range_high'] 		= loans['fico_range_high'].astype('int16')
loans['collections_12_mths_ex_med'] 	= loans['collections_12_mths_ex_med'].astype('float16')
loans['acc_now_delinq']			= loans['acc_now_delinq'].astype('int8')

loans['int_rate'] 				= loans['int_rate'].astype('float16')

# Anything else can be float32 instead of float64
for column in loans.select_dtypes(include=['float64']):
    loans[column] = loans[column].astype('float32')

# %% [markdown]
# ### Flag loans as good or bad
# Anything that isn't fully paid or current is considered bad

# %%
loans['bad'] =  (~loans.loan_status.isin( ['Fully Paid', 'Current'] )).astype('int8')

# %% [markdown]
# ### Finish up and save to pickle
# Using pickle just so it's easier to load into other scripts for analytics

# %%
loans.set_index( 'id', inplace=True )

# To pickle for use in other scripts
loans.to_pickle('C:\lc data\lc.pickle');

# %%
loans.head(5)
# Out:
#          member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# id
# 1077501    1296599       5000         5000             4975   36 months
# 1077430    1314167       2500         2500             2500   60 months
# 1077175    1313524       2400         2400             2400   36 months
# 1076863    1277178      10000        10000            10000   36 months
# 1075358    1311748       3000         3000             3000   60 months
#
#           int_rate  installment grade sub_grade                 emp_title  \
# id
# 1077501  10.648438   162.869995     B        B2                       NaN
# 1077430  15.273438    59.830002     C        C4                     Ryder
# 1077175  15.960938    84.330002     C        C5                       NaN
# 1076863  13.492188   339.309998     C        C1       AIR RESOURCES BOARD
# 1075358  12.687500    67.790001     B        B5  University Medical Group
#
#          emp_length home_ownership  annual_inc verification_status    issue_d  \
# id
# 1077501          10           RENT       24000            Verified 2011-12-01
# 1077430           1           RENT       30000     Source Verified 2011-12-01
# 1077175          10           RENT       12252        Not Verified 2011-12-01
# 1076863          10           RENT       49200     Source Verified 2011-12-01
# 1075358           1           RENT       80000     Source Verified 2011-12-01
#
#          loan_status pymnt_plan  \
# id
# 1077501   Fully Paid          n
# 1077430  Charged Off          n
# 1077175   Fully Paid          n
# 1076863   Fully Paid          n
# 1075358      Current          n
#
#                                                       desc         purpose  \
# id
# 1077501    I need to upgrade my business technologies.<br>     credit_card
# 1077430  I plan to use this money to finance the motorc...             car
# 1077175                                                NaN  small_business
# 1076863  to pay for property tax (borrow from friend, n...           other
# 1075358  I plan on combining three large interest bills...           other
#
#                         title  zip_code addr_state        dti  delinq_2yrs  \
# id
# 1077501              Computer     86000         AZ  27.650000            0
# 1077430                  bike     30900         GA   1.000000            0
# 1077175  real estate business     60600         IL   8.720000            0
# 1076863              personel     91700         CA  20.000000            0
# 1075358              Personal     97200         OR  17.940001            0
#
#         earliest_cr_line  fico_range_low  fico_range_high  inq_last_6mths  \
# id
# 1077501       1985-01-01             735              739               1
# 1077430       1999-04-01             740              744               5
# 1077175       2001-11-01             735              739               2
# 1076863       1996-02-01             690              694               1
# 1075358       1996-01-01             695              699               0
#
#          mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# id
# 1077501                     NaN                     NaN         3        0
# 1077430                     NaN                     NaN         3        0
# 1077175                     NaN                     NaN         2        0
# 1076863                    35.0                     NaN        10        0
# 1075358                    38.0                     NaN        15        0
#
#          revol_bal  revol_util  total_acc initial_list_status   out_prncp  \
# id
# 1077501      13648   83.687500          9                   f    0.000000
# 1077430       1687    9.398438          4                   f    0.000000
# 1077175       2956   98.500000         10                   f    0.000000
# 1076863       5598   21.000000         37                   f    0.000000
# 1075358      27783   53.906250         38                   f  766.900024
#
#          out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# id
# 1077501       0.000000   5861.071289      5831.779785      5000.000000
# 1077430       0.000000   1008.710022      1008.710022       456.459991
# 1077175       0.000000   3003.653564      3003.649902      2400.000000
# 1076863       0.000000  12226.301758     12226.299805     10000.000000
# 1075358     766.900024   3242.169922      3242.169922      2233.100098
#
#          total_rec_int  total_rec_late_fee  recoveries  \
# id
# 1077501     861.070007            0.000000    0.000000
# 1077430     435.170013            0.000000  117.080002
# 1077175     603.650024            0.000000    0.000000
# 1076863    2209.330078           16.969999    0.000000
# 1075358    1009.070007            0.000000    0.000000
#
#          collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d  \
# id
# 1077501                     0.00   2015-01-01       171.619995          NaT
# 1077430                     1.11   2013-04-01       119.660004          NaT
# 1077175                     0.00   2014-06-01       649.909973          NaT
# 1076863                     0.00   2015-01-01       357.480011          NaT
# 1075358                     0.00   2016-01-01        67.790001   2016-02-01
#
#         last_credit_pull_d  last_fico_range_high  last_fico_range_low  \
# id
# 1077501         2016-01-01                   739                  735
# 1077430         2013-09-01                   744                  740
# 1077175         2016-01-01                   739                  735
# 1076863         2015-01-01                   694                  690
# 1075358         2016-01-01                   699                  695
#
#          collections_12_mths_ex_med  mths_since_last_major_derog  \
# id
# 1077501                         0.0                          NaN
# 1077430                         0.0                          NaN
# 1077175                         0.0                          NaN
# 1076863                         0.0                          NaN
# 1075358                         0.0                          NaN
#
#          annual_inc_joint  dti_joint verification_status_joint  \
# id
# 1077501               NaN        NaN                       NaN
# 1077430               NaN        NaN                       NaN
# 1077175               NaN        NaN                       NaN
# 1076863               NaN        NaN                       NaN
# 1075358               NaN        NaN                       NaN
#
#          acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  \
# id
# 1077501               0           NaN          NaN          NaN         NaN
# 1077430               0           NaN          NaN          NaN         NaN
# 1077175               0           NaN          NaN          NaN         NaN
# 1076863               0           NaN          NaN          NaN         NaN
# 1075358               0           NaN          NaN          NaN         NaN
#
#          open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# id
# 1077501          NaN          NaN                 NaN           NaN      NaN
# 1077430          NaN          NaN                 NaN           NaN      NaN
# 1077175          NaN          NaN                 NaN           NaN      NaN
# 1076863          NaN          NaN                 NaN           NaN      NaN
# 1075358          NaN          NaN                 NaN           NaN      NaN
#
#          open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# id
# 1077501          NaN          NaN         NaN       NaN               NaN
# 1077430          NaN          NaN         NaN       NaN               NaN
# 1077175          NaN          NaN         NaN       NaN               NaN
# 1076863          NaN          NaN         NaN       NaN               NaN
# 1075358          NaN          NaN         NaN       NaN               NaN
#
#          inq_fi  total_cu_tl  inq_last_12m  bad
# id
# 1077501     NaN          NaN           NaN    0
# 1077430     NaN          NaN           NaN    1
# 1077175     NaN          NaN           NaN    0
# 1076863     NaN          NaN           NaN    0
# 1075358     NaN          NaN           NaN    0

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 884633 entries, 1077501 to 36271262
# Data columns (total 75 columns):
# member_id                      884633 non-null int32
# loan_amnt                      884633 non-null int32
# funded_amnt                    884633 non-null int32
# funded_amnt_inv                884633 non-null int32
# term                           884633 non-null object
# int_rate                       884633 non-null float16
# installment                    884633 non-null float32
# grade                          884633 non-null object
# sub_grade                      884633 non-null object
# emp_title                      833334 non-null object
# emp_length                     884633 non-null int8
# home_ownership                 884633 non-null object
# annual_inc                     884633 non-null int32
# verification_status            884633 non-null object
# issue_d                        884633 non-null datetime64[ns]
# loan_status                    884633 non-null object
# pymnt_plan                     884633 non-null object
# desc                           123606 non-null object
# purpose                        884633 non-null object
# title                          884484 non-null object
# zip_code                       884633 non-null int32
# addr_state                     884633 non-null object
# dti                            884633 non-null float32
# delinq_2yrs                    884633 non-null int8
# earliest_cr_line               884633 non-null datetime64[ns]
# fico_range_low                 884633 non-null int16
# fico_range_high                884633 non-null int16
# inq_last_6mths                 884633 non-null int8
# mths_since_last_delinq         431519 non-null float32
# mths_since_last_record         136193 non-null float32
# open_acc                       884633 non-null int8
# pub_rec                        884633 non-null int64
# revol_bal                      884633 non-null int32
# revol_util                     884171 non-null float16
# total_acc                      884633 non-null int8
# initial_list_status            884633 non-null object
# out_prncp                      884633 non-null float32
# out_prncp_inv                  884633 non-null float32
# total_pymnt                    884633 non-null float32
# total_pymnt_inv                884633 non-null float32
# total_rec_prncp                884633 non-null float32
# total_rec_int                  884633 non-null float32
# total_rec_late_fee             884633 non-null float32
# recoveries                     884633 non-null float32
# collection_recovery_fee        884633 non-null float32
# last_pymnt_d                   866986 non-null datetime64[ns]
# last_pymnt_amnt                884633 non-null float32
# next_pymnt_d                   631661 non-null datetime64[ns]
# last_credit_pull_d             884582 non-null datetime64[ns]
# last_fico_range_high           884633 non-null int16
# last_fico_range_low            884633 non-null int16
# collections_12_mths_ex_med     884577 non-null float16
# mths_since_last_major_derog    221704 non-null float32
# annual_inc_joint               511 non-null float32
# dti_joint                      509 non-null float32
# verification_status_joint      511 non-null object
# acc_now_delinq                 884633 non-null int8
# tot_coll_amt                   817106 non-null float32
# tot_cur_bal                    817106 non-null float32
# open_acc_6m                    21372 non-null float32
# open_il_6m                     21372 non-null float32
# open_il_12m                    21372 non-null float32
# open_il_24m                    21372 non-null float32
# mths_since_rcnt_il             20810 non-null float32
# total_bal_il                   21372 non-null float32
# il_util                        18617 non-null float32
# open_rv_12m                    21372 non-null float32
# open_rv_24m                    21372 non-null float32
# max_bal_bc                     21372 non-null float32
# all_util                       21372 non-null float32
# total_rev_hi_lim               817106 non-null float32
# inq_fi                         21372 non-null float32
# total_cu_tl                    21372 non-null float32
# inq_last_12m                   21372 non-null float32
# bad                            884633 non-null int8
# dtypes: datetime64[ns](5), float16(3), float32(34), int16(4), int32(7), int64(1), int8(7), object(14)
# memory usage: 297.8+ MB
